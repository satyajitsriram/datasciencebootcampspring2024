# %% [markdown]
# ## Satyajit Sriram Assignment 2 Submission

# %% [markdown]
# ###### Solutions to all questions in functions to observe modularity

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Question 1. From df filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0).
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df1.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
first = df1.iloc[::20, [0, 1, 2]]
print(first)
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# ##### 2) Replace missing values in Min.Price and Max.Price columns with their respective mean (check documentation).
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df2.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
# Calculating min price mean to fill
min_price_mean = df2['Min.Price'].mean()

# Calculating max price mean to fill
max_price_mean = df2['Max.Price'].mean()

# Replace missing values with mean
df2['Min.Price'].fillna(min_price_mean, inplace=True)
df2['Max.Price'].fillna(max_price_mean, inplace=True)

# %%
df2
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small  12.900000   15.9  18.800000      25.0
# 1           NaN   Legend  Midsize  29.200000   33.9  38.700000      18.0
# 2          Audi       90  Compact  25.900000   29.1  32.300000      20.0
# 3          Audi      100  Midsize  17.118605   37.7  44.600000      19.0
# 4           BMW     535i  Midsize  17.118605   30.0  21.459091      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van  16.600000   19.7  22.700000      17.0
# 89   Volkswagen   Passat  Compact  17.600000   20.0  22.400000      21.0
# 90   Volkswagen  Corrado   Sporty  22.900000   23.3  23.700000      18.0
# 91        Volvo      240  Compact  21.800000   22.7  23.500000      21.0
# 92          NaN      850  Midsize  24.800000   26.7  28.500000      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %% [markdown]
# ##### 3) How to get the rows of a dataframe with row sum > 100?
# df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))

# %%
df3 = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))

# %%
df3.head()
# Out:
#     0   1   2   3
# 0  35  15  38  34
# 1  31  35  19  17
# 2  11  32  20  37
# 3  20  32  39  17
# 4  23  32  17  12

# %%
third = df3[df3.sum(axis=1) > 100]

# %%
print("Rows with sum > 100")
third
# Out:
# Rows with sum > 100
#      0   1   2   3
# 0   35  15  38  34
# 1   31  35  19  17
# 3   20  32  39  17
# 8   23  29  38  12
# 12  21  38  28  27
# 13  27  19  33  31

# %% [markdown]
# ##### 4)Create a 4x4 NumPy array filled with random integers between 1 and 100. Then, reshape this array into two separate 2D arrays, where one represents the rows and the other represents the columns. Write a function, preferably using a lambda function, to calculate the sum of each row and each column separately, and return the results as two separate NumPy arrays

# %%
# Create a 4x4 NumPy array filled with random integers between 1 and 100
numpy4x4 = np.random.randint(1, 101, size=(4, 4))

# Reshape into two separate 2D arrays for rows and columns
rows_array = numpy4x4.reshape(2, 8)
columns_array = numpy4x4.T.reshape(2, 8)

# Function to calculate the sum of each row and column separately using lambda functions
sum_row = lambda array: np.sum(array, axis=1)
sum_column = lambda array: np.sum(array, axis=0)

# Calculate the sums of rows and columns separately
sums_of_rows = sum_row(rows_array)
sums_of_columns = sum_column(columns_array)

# %%
print("Sums of Rows:", sums_of_rows)
print("Sums of Columns:", sums_of_columns)
# Out:
# Sums of Rows: [514 469]
# Sums of Columns: [114 137 176  77 135 128  67 149]
